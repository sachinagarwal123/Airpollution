# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gs
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_excel('/content/real_estate_leads (1).xlsx')
df.drop(columns=['lead_id', 'customer_name', 'customer_phone', 'date'], inplace=True)

# %%
print(df)
# Out:
#             source property_type       location  bedrooms  bathrooms  \
# 0              OCR         Villa          Ajman       2.0        1.0
# 1          Website         Villa  Umm Al Quwain       2.0        1.0
# 2           Google     Penthouse          Dubai       1.0        1.0
# 3      Call Center     Penthouse  Umm Al Quwain       3.0        2.0
# 4      Call Center     Apartment  Umm Al Quwain       4.0        2.0
# ...            ...           ...            ...       ...        ...
# 99995     WhatsApp     Penthouse  Umm Al Quwain       5.0        1.0
# 99996          OCR        Studio        Sharjah       3.0        3.0
# 99997    Instagram     Apartment        Sharjah       1.0        3.0
# 99998     WhatsApp     Townhouse          Dubai       1.0        1.0
# 99999       Google         Villa        Sharjah       4.0        2.0
#
#        property_size_sqft  price_AED contact_method budget_range  \
# 0                    9326    1136104           Call    100k-200k
# ...

# %%
cat_cols = ['source', 'property_type', 'location'
'contact_method', 'budget_range']
num_cols = ['bedrooms', 'bathrooms','price_AED',
            'property_size_sqft', 'contact_attempts',
            'response_time_hours', 'interest_level']

# %%
le_dict = {}
le = LabelEncoder()
for col in cat_cols:
  df[col] = le.fit_transform(df[col].astype(str))
  le_dict[col] = le

df['purchased_before'] = df['purchased_before'].astype(int)

# %%
# Handle missg values (Dropped or impute)
# extract lead year lead month
#Handle categorical features using OneHotencoder

# model selection Random forest classifier
# benfits of RFC works good with mixed features
#feature importance also provides

#model testing
# 80% data for training
# 20% data for testing

# model evaluate
# Precision, Recall, F1-score, ROC also
